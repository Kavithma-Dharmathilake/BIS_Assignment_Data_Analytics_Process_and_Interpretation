# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavithma-Dharmathilake/BIS_Assignment_Data_Analytics_Process_and_Interpretation/blob/main/Notebook_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Data Analytics Process and Interpretation
#
# ---

# %% [markdown]
# Student Information : K. A. D. K.D.Dharmathilake
#
# Dataset Link: https://archive.ics.uci.edu/dataset/296/diabetes+130-us+hospitals+for+years+1999-2008

# %% [markdown]
# **About the Dataset**
#
# The dataset represents ten years (1999-2008) of clinical care at 130 US hospitals and integrated delivery networks. Each row concerns hospital records of patients diagnosed with diabetes, who underwent laboratory, medications, and stayed up to 14 days. The goal is to determine the early readmission of the patient within 30 days of discharge. The problem is important for the following reasons. Despite high-quality evidence showing improved clinical outcomes for diabetic patients who receive various preventive and therapeutic interventions, many patients do not receive them. This can be partially attributed to arbitrary diabetes management in hospital environments, which fail to attend to glycemic control. Failure to provide proper diabetes care not only increases the managing costs for the hospitals (as the patients are readmitted) but also impacts the morbidity and mortality of the patients, who may face complications associated with diabetes.

# %% [markdown]
# ## Table of Content
#
#
# **1. Problem Definition**
#
# **2. Dataset Understanding**
#
#     2.1.Independent Variables
#
#     2.2. Target Variable
#
# **3. Data Preprocessing**
#
#     2.1.Independent Variables
#
#     2.2. Target Variable
#
# **4.  Data Preprocessing**
#
#     4.1.Load Dataset
#
#     4.2.Install Python Libraries
#
#     4.3.Missing Values
#
#     4.4.Encode Variables
#
#     4.5.Duplicate Values
#
# **5. Exploratory Data Analysis(EDA)**
#
#     5.1.Demographics
#
#     5.2.Admission & Hospital Stay Details
#
#     5.3.Diagnosis
#
#     5.4.Drugs
#
#     5.5.Target Variable
# **6.  Bivariate/multivariate analysis**
#
#     6.1.Numerical vs Numerical
#
#     6.2.Numerical vs Categorical
#
#     6.3.Categorical vs Categorical
#
#     6.4.Analysis with Target Variable
#
#
# -----

# %% [markdown]
# ## 1. Problem Definition
#
# **Business Context:**
#
# Data analyst in a hospital network where the company
# Management wants to reduce 30-day readmission rates because:
#
# Readmissions increase costs
#
# *   They reduce quality ratings
# *   They affect insurance reimbursements
#
# **Business Question:**
#
#
# > **What factors influence 30-day hospital readmission among diabetic patients, and can we predict which patients are at high risk?**
#
#
#
#
#
#
# ---

# %% [markdown]
# ## 2. Dataset Understanding

# %% [markdown]
# Understanding the dimensions as given in the description page.
#
# | No | Variable Name | Role | Type | Demographic | Description | Units | Missing Values |
# |----|--------------|------|------|------------|------------|-------|----------------|
# | 1 | encounter_id | ID | — | — | Unique identifier assigned to each hospital encounter (visit/admission). | — | no |
# | 2 | patient_nbr | ID | — | — | Unique identifier assigned to each individual patient. | — | no |
# | 3 | race | Feature | Categorical | Race | Patient’s race. Values include Caucasian, Asian, African American, Hispanic, and Other. | — | yes |
# | 4 | gender | Feature | Categorical | Gender | Patient’s gender. Values: Male, Female, Unknown/Invalid. | — | no |
# | 5 | age | Feature | Categorical | Age | Patient’s age grouped into 10-year intervals: [0–10), [10–20), …, [90–100). | years (grouped) | no |
# | 6 | weight | Feature | Categorical | — | Patient’s weight measured in pounds (grouped categories in dataset). | pounds | yes |
# | 7 | admission_type_id | Feature | Categorical | — | Integer identifier representing the type of admission (9 categories), e.g., emergency, urgent, elective, newborn, not available. | — | no |
# | 8 | discharge_disposition_id | Feature | Categorical | — | Integer identifier indicating the patient’s discharge status (29 categories), e.g., discharged home, transferred, expired. | — | no |
# | 9 | admission_source_id | Feature | Categorical | — | Integer identifier representing the source of admission (21 categories), e.g., physician referral, emergency room, hospital transfer. | — | no |
# | 10 | time_in_hospital | Feature | Integer | — | Total number of days the patient stayed in the hospital during the encounter. | days | no |
# | 11 | payer_code | Feature | Categorical | — | Identifier of the payer/insurance type (23 categories), e.g., Blue Cross/Blue Shield, Medicare, Medicaid, self-pay. | — | yes |
# | 12 | medical_specialty | Feature | Categorical | — | Medical specialty of the admitting physician (84 categories), e.g., cardiology, internal medicine, family practice, surgery. | — | yes |
# | 13 | num_lab_procedures | Feature | Integer | — | Number of laboratory tests performed during the encounter. | count | no |
# | 14 | num_procedures | Feature | Integer | — | Number of medical procedures (excluding lab tests) performed during the encounter. | count | no |
# | 15 | num_medications | Feature | Integer | — | Number of distinct medications administered during the encounter. | count | no |
# | 16 | number_outpatient | Feature | Integer | — | Number of outpatient visits the patient had in the year preceding this encounter. | count | no |
# | 17 | number_emergency | Feature | Integer | — | Number of emergency department visits in the year preceding this encounter. | count | no |
# | 18 | number_inpatient | Feature | Integer | — | Number of inpatient admissions in the year preceding this encounter. | count | no |
# | 19 | diag_1 | Feature | Categorical | — | Primary diagnosis code (first three digits of ICD-9); 848 distinct values. | ICD-9 code | yes |
# | 20 | diag_2 | Feature | Categorical | — | Secondary diagnosis code (first three digits of ICD-9); 923 distinct values. | ICD-9 code | yes |
# | 21 | diag_3 | Feature | Categorical | — | Additional secondary diagnosis code (first three digits of ICD-9); 954 distinct values. | ICD-9 code | yes |
# | 22 | number_diagnoses | Feature | Integer | — | Total number of diagnoses recorded for the patient during the encounter. | count | no |
# | 23 | max_glu_serum | Feature | Categorical | — | Maximum serum glucose test result. Values: >200, >300, normal, or none (if test not measured). | — | no |
# | 24 | A1Cresult | Feature | Categorical | — | Hemoglobin A1C test result. Values: >8%, >7% and </8%, normal (</7%), or none (if not measured). | percentage category | no |
# | 25 | metformin | Feature | Categorical | — | Indicates whether metformin was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 26 | repaglinide | Feature | Categorical | — | Indicates whether repaglinide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 27 | nateglinide | Feature | Categorical | — | Indicates whether nateglinide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 28 | chlorpropamide | Feature | Categorical | — | Indicates whether chlorpropamide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 29 | glimepiride | Feature | Categorical | — | Indicates whether glimepiride was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 30 | acetohexamide | Feature | Categorical | — | Indicates whether acetohexamide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 31 | glipizide | Feature | Categorical | — | Indicates whether glipizide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 32 | glyburide | Feature | Categorical | — | Indicates whether glyburide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 33 | tolbutamide | Feature | Categorical | — | Indicates whether tolbutamide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 34 | pioglitazone | Feature | Categorical | — | Indicates whether pioglitazone was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 35 | rosiglitazone | Feature | Categorical | — | Indicates whether rosiglitazone was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 36 | acarbose | Feature | Categorical | — | Indicates whether acarbose was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 37 | miglitol | Feature | Categorical | — | Indicates whether miglitol was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 38 | troglitazone | Feature | Categorical | — | Indicates whether troglitazone was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 39 | tolazamide | Feature | Categorical | — | Indicates whether tolazamide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 40 | examide | Feature | Categorical | — | Indicates whether examide was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 41 | citoglipton | Feature | Categorical | — | Indicates whether citoglipton was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 42 | insulin | Feature | Categorical | — | Indicates whether insulin was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 43 | glyburide-metformin | Feature | Categorical | — | Indicates whether the glyburide–metformin combination drug was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 44 | glipizide-metformin | Feature | Categorical | — | Indicates whether the glipizide–metformin combination drug was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 45 | glimepiride-pioglitazone | Feature | Categorical | — | Indicates whether the glimepiride–pioglitazone combination drug was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 46 | metformin-rosiglitazone | Feature | Categorical | — | Indicates whether the metformin–rosiglitazone combination drug was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 47 | metformin-pioglitazone | Feature | Categorical | — | Indicates whether the metformin–pioglitazone combination drug was prescribed and whether its dosage changed during the encounter. Values: up, down, steady, no. | — | no |
# | 48 | change | Feature | Categorical | — | Indicates whether there was any change in diabetic medications (dosage adjustment or medication switch). Values: change, no change. | — | no |
# | 49 | diabetesMed | Feature | Categorical | — | Indicates whether any diabetic medication was prescribed during the encounter. Values: yes, no. | — | no |
# | 50 | readmitted | Target | Categorical | — | Indicates hospital readmission status. Values: <30 (readmitted within 30 days), >30 (readmitted after 30 days), No (no readmission). | — | no |

# %% [markdown]
# Dataset has total 50 columns, 47 features.
#
#
# There are missing values as given in the description page.
#
# > race, weight, payer_code, medical_specialty, diag_1, diag_2, diag_3 <-- data missing

# %% [markdown]
# ### Independent Variables
#
# The independent variables represent patient characteristics, hospital encounter details, clinical measurements, and medication-related information used to predict hospital readmission.
#
#
# **1. Patient Identifiers & Demographics**
#
# encounter_id, patient_nbr, race, gender, age, weight
#
# **2. Admission & Hospital Stay Details**
#
# admission_type_id, discharge_disposition_id, admission_source_id, time_in_hospital, payer_code, medical_specialty, num_lab_procedures, num_procedures, num_medications, number_outpatient, number_emergency, number_inpatient
#
#
# **3. Clinical Measures & Diagnostic Data**
#
# diag_1, diag_2, diag_3, number_diagnoses, max_glu_serum, A1Cresult
#
#
# **4. Medication Features (24 Drugs)**
#
# metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, acetohexamide, glipizide, glyburide, tolbutamide, pioglitazone, rosiglitazone, acarbose, miglitol, troglitazone, tolazamide, examide, citoglipton, insulin, glyburide-metformin, glipizide-metformin, glimepiride-pioglitazone, metformin-rosiglitazone, metformin-pioglitazone, change, diabetesMed

# %% [markdown]
# ###Target Variable
#
# > readmitted
#
#
# The readmitted variable indicates whether a patient was readmitted after discharge.
#
# It has three categories:
#
#
# 1.   <30 (readmitted within 30 days)
# 2.   \>30 (readmitted after 30 days),
# 3.   No (no readmission recorded).

# %% [markdown]
# **Numerical Independent Variables**
#
# time_in_hospital, num_lab_procedures, num_procedures, num_medications, number_outpatient, number_emergency, number_inpatient, number_diagnoses
#
# **Categorical Independent Variables**
#
# race, gender, age, weight, admission_type_id, discharge_disposition_id, admission_source_id, payer_code, medical_specialty, diag_1, diag_2, diag_3, max_glu_serum, A1Cresult, metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, acetohexamide, glipizide, glyburide, tolbutamide, pioglitazone, rosiglitazone, acarbose, miglitol, troglitazone, tolazamide, examide, citoglipton, insulin, glyburide-metformin, glipizide-metformin, glimepiride-pioglitazone, metformin-rosiglitazone, metformin-pioglitazone, change, diabetesMed
#
#
#
# ---

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### Load Dataset

# %%
#Loading the data
import pandas as pd

df = pd.read_csv("diabetic_data.csv", keep_default_na=False)

# %% [markdown]
# ### Install Python Libraries

# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()

print("Categorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: ['race', 'gender', 'age', 'weight', 'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted']
# Numerical columns: ['encounter_id', 'patient_nbr', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses']

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Missing values in this dataset are represented by ‘?’.

# %%
# Replace only '?' with NaN
df = df.replace("?", np.nan)

# %%
total_cells = df.size
missing_cells = df.isna().sum().sum()

missing_percentage = (missing_cells / total_cells) * 100

print(f"Total entries: {101766}")
print(f"Missing values: {missing_cells}")
print(f"Missing percentage: {missing_percentage:.2f}%")
# Out:
# Total entries: 101766
# Missing values: 192849
# Missing percentage: 3.79%

# %%
total_rows = len(df)

missing_count = df.isna().sum()

missing_percentage = (missing_count / total_rows) * 100

summary_table = pd.DataFrame({
    "feature": df.columns,
    "missing_count": missing_count.values,
    "missing_percentage": missing_percentage.values
})

# Keep only columns where missing_count > 0
summary_table = summary_table[summary_table["missing_count"] > 0]

# Sort by highest missing %
summary_table = summary_table.sort_values(
    by="missing_percentage",
    ascending=False
)

summary_table
# Out:
#               feature  missing_count  missing_percentage
# 5              weight          98569           96.858479
# 11  medical_specialty          49949           49.082208
# 10         payer_code          40256           39.557416
# 2                race           2273            2.233555
# 20             diag_3           1423            1.398306
# 19             diag_2            358            0.351787
# 18             diag_1             21            0.020636

# %%
import seaborn as sns
import matplotlib.pyplot as plt


cols_with_missing = df.columns[df.isna().sum() > 0]

df_missing = df[cols_with_missing]

plt.figure(figsize=(12,6))
sns.heatmap(df_missing.isna(),
            cbar=True,
            yticklabels=False)

plt.title("Heatmap of Missing Values (Filtered Columns)")
plt.show()

# %% [markdown]
# Total number of entries are 101766
#
# Note the folllwing features in heatmap
#
# >'race', 'weight', 'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3'
#
#
#
# They contain **missing values**

# %% [markdown]
# weight column can be directly dropped because 96% is missing.

# %%
df = df.drop(columns=["weight"])

# %% [markdown]
# payer code will be dropped as we are not interested in it.

# %%
df = df.drop(columns=["payer_code"])

# %% [markdown]
# Let's first fill the rest of column with 'unknown'  and diagnosis value with mode(most frequent number)

# %%
df['medical_specialty'].fillna('Unknown', inplace=True)
df['race'].fillna('Unknown', inplace=True)
for col in ['diag_1','diag_2','diag_3']:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-2738338964.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['medical_specialty'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-2738338964.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# With this all the missing values are handled.

# %% [markdown]
# ### Encode Variables

# %% [markdown]
# Under this section categorical variables will be encoded.

# %% [markdown]
# The values of age are given like [0–10),[10–20),[20–30)
#
# The age feature is ordinal and it is converted as bellow,
#
# [0–10) → 5, [10–20) → 15, [20–30) — -> 25

# %%
#Encode Age Values

import re

def convert_age(age_range):
    if pd.isna(age_range):
        return age_range
    numbers = list(map(int, re.findall(r'\d+', age_range)))
    return sum(numbers) / 2

df['age'] = df['age'].apply(convert_age)

# %% [markdown]
# for diag_1, diag_2, diag_3 , They are high-cardinality categorical variables. We might need to categorize these ICD9 codes before analysing them.
#
# please refer this wikipedia link for futhure understanding:
#
# https://en.wikipedia.org/wiki/List_of_ICD-9_codes

# %%
# Function to Map ICD Codes

def map_icd9_to_category(code):
    if pd.isna(code):
        return 'Other'

    # Handle E codes
    if code.startswith('E'):
        return 'External Causes / Injury'

    # Handle V codes
    if code.startswith('V'):
        return 'Supplemental / Other'

    # Convert numeric part to int
    try:
        num = int(code[:3])
    except:
        return 'Other'

    if 1 <= num <= 139:
        return 'Infectious and parasitic diseases'
    elif 140 <= num <= 239:
        return 'Neoplasms'
    elif 240 <= num <= 279:
        return 'Endocrine, nutritional, metabolic, immunity disorders'
    elif 280 <= num <= 289:
        return 'Blood diseases'
    elif 290 <= num <= 319:
        return 'Mental disorders'
    elif 320 <= num <= 389:
        return 'Nervous system & sense organs'
    elif 390 <= num <= 459:
        return 'Circulatory system'
    elif 460 <= num <= 519:
        return 'Respiratory system'
    elif 520 <= num <= 579:
        return 'Digestive system'
    elif 580 <= num <= 629:
        return 'Genitourinary system'
    elif 630 <= num <= 679:
        return 'Pregnancy/Childbirth complications'
    elif 680 <= num <= 709:
        return 'Skin & subcutaneous tissue'
    elif 710 <= num <= 739:
        return 'Musculoskeletal & connective tissue'
    elif 740 <= num <= 759:
        return 'Congenital anomalies'
    elif 760 <= num <= 779:
        return 'Perinatal conditions'
    elif 780 <= num <= 799:
        return 'Symptoms & ill-defined conditions'
    elif 800 <= num <= 999:
        return 'Injury & poisoning'
    else:
        return 'Other'

# %%
for col in ['diag_1', 'diag_2', 'diag_3']:
    df[col + '_group'] = df[col].apply(map_icd9_to_category)
# New feature was created based on Domain Information as diag_1_group, diag_2_group etc.)

# %%
icd9_category_map = {
    'Infectious and parasitic diseases': 1,
    'Neoplasms': 2,
    'Endocrine, nutritional, metabolic, immunity disorders': 3,
    'Blood diseases': 4,
    'Mental disorders': 5,
    'Nervous system & sense organs': 6,
    'Circulatory system': 7,
    'Respiratory system': 8,
    'Digestive system': 9,
    'Genitourinary system': 10,
    'Pregnancy/Childbirth complications': 11,
    'Skin & subcutaneous tissue': 12,
    'Musculoskeletal & connective tissue': 13,
    'Congenital anomalies': 14,
    'Perinatal conditions': 15,
    'Symptoms & ill-defined conditions': 16,
    'Injury & poisoning': 17,
    'External Causes / Injury': 18,
    'Supplemental / Other': 19,
    'Other': 20
}

for col in ['diag_1_group','diag_2_group','diag_3_group']:
    # Map ICD codes to category first
    df[col] = df[col].apply(map_icd9_to_category)
    # Then map category to number
    df[col] = df[col].map(icd9_category_map)

# %% [markdown]
# something went wrong here .check.

# %%
df['diag_1_group']
# Out:
# 0         18
# 1         18
# 2         20
# 3         20
# 4         20
#           ..
# 101761    18
# 101762    20
# 101763    20
# 101764    20
# 101765    20
# Name: diag_1_group, Length: 101766, dtype: int64

# %%
mapping = {
    "None": 0,
    "Norm": 1,
    ">200": 2,
    ">300": 3
}

df["max_glu_serum"] = df["max_glu_serum"].map(mapping)

# %%
mapping = {
    "None": 0,
    "Norm": 1,
    ">7": 2,
    ">8": 3
}

df["A1Cresult"] = df["A1Cresult"].map(mapping)

# %%
# Check Categorical variables
df['race'].value_counts(normalize=True) * 100
# Out:
# race
# Caucasian          74.778413
# AfricanAmerican    18.876639
# Unknown             2.233555
# Hispanic            2.001651
# Other               1.479866
# Asian               0.629876
# Name: proportion, dtype: float64

# %%
race_map = {
    'Caucasian': 1,
    'AfricanAmerican': 2,
    'Hispanic': 3,
    'Asian': 4,
    'Other': 5,
    'Unknown': 6
}

df['race'] = df['race'].map(race_map)

# %%
df['gender'].value_counts(normalize=True) * 100
# Out:
# gender
# Female             53.758623
# Male               46.238429
# Unknown/Invalid     0.002948
# Name: proportion, dtype: float64

# %%
df['gender'] = df['gender'].map({'Male':0, 'Female':1,'Unknown/Invalid': -1 })

# %%
df['medical_specialty'].value_counts(normalize=True) * 100
# Out:
# medical_specialty
# Unknown                   49.082208
# InternalMedicine          14.381031
# Emergency/Trauma           7.433720
# Family/GeneralPractice     7.310890
# Cardiology                 5.259124
#                             ...
# Proctology                 0.000983
# Speech                     0.000983
# SportsMedicine             0.000983
# Perinatology               0.000983
# Neurophysiology            0.000983
# Name: proportion, Length: 73, dtype: float64

# %% [markdown]
# Medical Speciality has too many distinct values.
#
# Lets group them first with domain knowledge

# %%
# First, define your groups (as you provided)
high_frequency = ['InternalMedicine', 'Family/GeneralPractice', 'Cardiology', 'Surgery-General',
                  'Orthopedics', 'Orthopedics-Reconstructive', 'Emergency/Trauma', 'Urology',
                  'ObstetricsandGynecology','Psychiatry','Pulmonology ','Nephrology','Radiologist']

low_frequency = ['Surgery-PlasticwithinHeadandNeck','Psychiatry-Addictive','Proctology','Dermatology',
                 'SportsMedicine','Speech','Perinatology','Neurophysiology','Resident','Pediatrics-Hematology-Oncology',
                 'Pediatrics-EmergencyMedicine','Dentistry','DCPTEAM','Psychiatry-Child/Adolescent',
                 'Pediatrics-Pulmonology','Surgery-Pediatric','AllergyandImmunology','Pediatrics-Neurology',
                 'Anesthesiology','Pathology','Cardiology-Pediatric','Endocrinology-Metabolism','PhysicianNotFound',
                 'Surgery-Colon&Rectal','OutreachServices','Surgery-Maxillofacial','Rheumatology','Anesthesiology-Pediatric',
                 'Obstetrics','Obsterics&Gynecology-GynecologicOnco']

pediatrics = ['Pediatrics','Pediatrics-CriticalCare','Pediatrics-EmergencyMedicine','Pediatrics-Endocrinology',
              'Pediatrics-Hematology-Oncology','Pediatrics-Neurology','Pediatrics-Pulmonology',
              'Anesthesiology-Pediatric','Cardiology-Pediatric','Surgery-Pediatric']

psychic = ['Psychiatry-Addictive', 'Psychology', 'Psychiatry',  'Psychiatry-Child/Adolescent',
           'PhysicalMedicineandRehabilitation', 'Osteopath']

neurology = ['Neurology', 'Surgery-Neuro',  'Pediatrics-Neurology', 'Neurophysiology']

surgery = ['Surgeon', 'Surgery-Cardiovascular','Surgery-Cardiovascular/Thoracic','Surgery-Colon&Rectal',
           'Surgery-General','Surgery-Maxillofacial','Surgery-Plastic','Surgery-PlasticwithinHeadandNeck',
           'Surgery-Thoracic','Surgery-Vascular','SurgicalSpecialty','Podiatry']

ungrouped = ['Endocrinology','Gastroenterology','Gynecology','Hematology','Hematology/Oncology','Hospitalist',
             'InfectiousDiseases','Oncology','Ophthalmology','Otolaryngology','Pulmonology','Radiology']

missing = ['Unknown']

def map_medical_specialty_to_num(spec):
    if spec in high_frequency:
        return 1
    elif spec in low_frequency:
        return 2
    elif spec in pediatrics:
        return 3
    elif spec in psychic:
        return 4
    elif spec in neurology:
        return 5
    elif spec in surgery:
        return 6
    elif spec in ungrouped:
        return 7
    elif spec in missing or pd.isna(spec):
        return 8
    else:
        return 9  # Catch-all for any unexpected specialty

df['medical_specialty_group_num'] = df['medical_specialty'].apply(map_medical_specialty_to_num)

# %%
# Handling Drug Types

for col in ["metformin", "repaglinide", "nateglinide", "chlorpropamide", "glimepiride", "acetohexamide", "glipizide", "glyburide", "tolbutamide", "pioglitazone", "rosiglitazone", "acarbose", "miglitol", "troglitazone", "tolazamide", "examide", "citoglipton", "insulin", "glyburide-metformin", "glipizide-metformin", "glimepiride-pioglitazone", "metformin-rosiglitazone", "metformin-pioglitazone"]:
    df[col] = df[col].apply(lambda x : 10 if x == 'Up'
                                              else ( -10 if x == 'Down'
                                              else ( 0 if x == 'Steady'
                                              else  -20)))

# %%
df['change'] = df['change'].apply(lambda x : 1 if x == 'Ch'
                                                 else -1)


df['diabetesMed'] = df['diabetesMed'].apply(lambda x : -1 if x == 'No'
                                                else 1)

# %%
df['readmitted'].value_counts()
# Out:
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: count, dtype: int64

# %%
df['readmitted'] = df['readmitted'].replace({
    '<30': 1,
    '>30': 0,
    'NO': -1
})
# Out:
# /tmp/ipython-input-1306632705.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['readmitted'] = df['readmitted'].replace({

# %% [markdown]
# ### Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# no rows are duplicated.
#
# Let's see whether IDs (encounder_id, patient_nbr) got duplicated

# %%
df['encounter_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Encounter ID is not needed. I will drop it

# %%
df.drop(['encounter_id'], axis=1, inplace=True)

# %%
df['patient_nbr'].duplicated().sum()
# Out:
# np.int64(30248)

# %%
df[df['patient_nbr'].duplicated(keep=False)].sort_values('patient_nbr')
# Out:
#         patient_nbr  race  gender   age  admission_type_id  \
# 4780            135     1       1  55.0                  1
# 4267            135     1       1  55.0                  2
# 5953           1152     2       1  55.0                  1
# 23623          1152     2       1  65.0                  1
# 14180          1152     2       1  65.0                  1
# ...             ...   ...     ...   ...                ...
# 95640     188634893     1       0  75.0                  3
# 93050     188970179     4       1  75.0                  1
# 101595    188970179     4       1  75.0                  1
# 90933     189257846     4       0  65.0                  1
# 98191     189257846     4       0  65.0                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 4780                           1                    7                 3
# 4267                           1                    1                 8
# ...

# %% [markdown]
# Patient ID is duplicated.
# A patient can appear multiple times (multiple hospital visits).
# So duplicates here are normal.
#
# Let's treat them as independent for predicting readmission.

# %%
# Columns to compare (exclude patient_nbr and encounter_id)
cols_to_check = df.columns.difference(['patient_nbr', 'encounter_id'])

# Find duplicates for the same patient
duplicates_same_patient = df[df.duplicated(subset=['patient_nbr'] + list(cols_to_check), keep=False)]
duplicates_same_patient = duplicates_same_patient.sort_values('patient_nbr')

# Show a sample
duplicates_same_patient.head(10)
# Out:
# Empty DataFrame
# Columns: [patient_nbr, race, gender, age, admission_type_id, discharge_disposition_id, admission_source_id, time_in_hospital, medical_specialty, num_lab_procedures, num_procedures, num_medications, number_outpatient, number_emergency, number_inpatient, diag_1, diag_2, diag_3, number_diagnoses, max_glu_serum, A1Cresult, metformin, repaglinide, nateglinide, chlorpropamide, glimepiride, acetohexamide, glipizide, glyburide, tolbutamide, pioglitazone, rosiglitazone, acarbose, miglitol, troglitazone, tolazamide, examide, citoglipton, insulin, glyburide-metformin, glipizide-metformin, glimepiride-pioglitazone, metformin-rosiglitazone, metformin-pioglitazone, change, diabetesMed, readmitted, diag_1_group, diag_2_group, diag_3_group, medical_specialty_group_num]
# Index: []
#
# [0 rows x 51 columns]

# %% [markdown]
# Above shows same patient has different records during different encounters.

# %%
# Calculate percentage of rows that have the same value per column
constant_percentage = {}

for col in df.columns:
    most_freq = df[col].value_counts().max()
    total = df.shape[0]
    constant_percentage[col] = (most_freq / total) * 100

# Convert to a DataFrame for easy viewing
constant_df = pd.DataFrame.from_dict(constant_percentage, orient='index', columns=['most_common_value_percentage'])
constant_df = constant_df.sort_values(by='most_common_value_percentage', ascending=False)

print(constant_df)
# Out:
#                              most_common_value_percentage
# citoglipton                                    100.000000
# examide                                        100.000000
# acetohexamide                                   99.999017
# glimepiride-pioglitazone                        99.999017
# metformin-pioglitazone                          99.999017
# metformin-rosiglitazone                         99.998035
# troglitazone                                    99.997052
# glipizide-metformin                             99.987226
# tolbutamide                                     99.977399
# miglitol                                        99.962659
# tolazamide                                      99.961677
# chlorpropamide                                  99.915492
# acarbose                                        99.697345
# nateglinide                                     99.309200
# glyburide-metformin                             99.306252
# ...

# %% [markdown]
# Here note the top most drugs which has almost similar values accross all patient encounters. This has very less predictive values.
#
# For an example citoglipton  is 100 %. Which means every row has same value. Such features hold less meaning for the data analysis. Those are safe to drop, as they have less use for predicting patterns or trends accorss.
#
#
# So the drugs above 99% similarity was dropped from the Dataframe

# %%
# Calculate % of most frequent value per column
constant_percentage = df.apply(lambda x: x.value_counts(normalize=True).max() * 100)

# Columns to drop: ≥ 99% constant
cols_to_drop = constant_percentage[constant_percentage >= 99].index.tolist()

# Drop those columns
df.drop(columns=cols_to_drop, inplace=True)

print(f"Dropped {len(cols_to_drop)} columns with ≥ 99% constant values.")
print("Remaining columns:", df.shape[1])
# Out:
# Dropped 15 columns with ≥ 99% constant values.
# Remaining columns: 36

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Exploratory Data Analysis(EDA)

# %% [markdown]
# Finalized column as bellow.
#
# 1. Patient Identifiers & Demographics
#
# race, gender, age
#
# 2. Admission & Hospital Stay Details
#
# admission_type_id, discharge_disposition_id, admission_source_id, time_in_hospital, medical_specialty_group_num, num_lab_procedures, num_procedures, num_medications, number_outpatient, number_emergency, number_inpatient
#
# 3. Clinical Measures & Diagnostic Data
#
# number_diagnoses, max_glu_serum, A1Cresult, diag_1_group, diag_2_group, diag_3_group
#
# 4. Medication Features
#
# metformin, repaglinide, glimepiride, glipizide, glyburide, pioglitazone, rosiglitazone, insulin, diabetesMed, change
#
#
# Under this section simple EDA will be visualized

# %% [markdown]
# First let's do a univariate analysis

# %% [markdown]
# ### Demographics

# %%
import matplotlib.pyplot as plt
import seaborn as sns


race_map = {
    'Caucasian': 1,
    'AfricanAmerican': 2,
    'Hispanic': 3,
    'Asian': 4,
    'Other': 5,
    'Unknown': 6
}
df['race_num'] = df['race'].map(race_map)
df['gender_num'] = df['gender'].map({'Male':0, 'Female':1,'Unknown/Invalid': -1 })


age_color = "#A78BFA"        # light purple
race_colors = ["#D8B4FE", "#C084FC", "#A855F7", "#9333EA", "#7E22CE", "#6B21A8"]
gender_colors = ["#C084FC", "#9333EA", "#6B21A8"]

# -----------------------
# 1. Age histogram (full width)
# -----------------------
plt.figure(figsize=(10,5))
sns.histplot(df['age'], bins=10, kde=True, color=age_color)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# -----------------------
# 2. Pie charts for race and gender side by side
# -----------------------
fig, axes = plt.subplots(1, 2, figsize=(12,6))

# Race pie chart
race_counts = df['race'].value_counts()
axes[0].pie(race_counts, labels=race_counts.index, autopct='%1.1f%%', colors=race_colors, startangle=140, textprops={'fontsize':12})
axes[0].set_title("Race Distribution", fontsize=14)

# Gender pie chart
gender_counts = df['gender'].value_counts()
axes[1].pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=gender_colors, startangle=140, textprops={'fontsize':12})
axes[1].set_title("Gender Distribution", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# Highest number of encounters are between **60-80 in age**.
#
# Most encounters with **Caucasian** while least from **Asian**
#
# Number of encounters in **Female** is higher than **Male**

# %% [markdown]
# ### Admission & Hospital Stay Details

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# List of numerical and categorical features
categorical_features = ['admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'medical_specialty_group_num']
numerical_features = ['time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications',
                      'number_outpatient', 'number_emergency', 'number_inpatient']

# -----------------------
# 1. Categorical features - count plots
# -----------------------
fig, axes = plt.subplots(2, 2, figsize=(16,10))

for ax, col in zip(axes.flatten(), categorical_features):
    sns.countplot(data=df, x=col, ax=ax, palette="Purples")
    ax.set_title(f"{col} Distribution")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")

plt.tight_layout()
plt.show()

# -----------------------
# 2. Numerical features - histograms + boxplots
# -----------------------
fig, axes = plt.subplots(len(numerical_features), 2, figsize=(14, 5*len(numerical_features)))

for i, col in enumerate(numerical_features):
    # Histogram
    sns.histplot(df[col], bins=20, kde=True, color="#A78BFA", ax=axes[i,0])
    axes[i,0].set_title(f"{col} Distribution (Histogram)")
    axes[i,0].set_xlabel(col)
    axes[i,0].set_ylabel("Count")

    # Boxplot
    sns.boxplot(data=df, y=col, color="#9333EA", ax=axes[i,1])
    axes[i,1].set_title(f"{col} Distribution (Boxplot)")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4192780451.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette="Purples")
# /tmp/ipython-input-4192780451.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette="Purples")
# /tmp/ipython-input-4192780451.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette="Purples")
# /tmp/ipython-input-4192780451.py:17: FutureWarning:
#
# ...

# %% [markdown]
# Put a comment Here

# %% [markdown]
# ### Diagnosis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

fig, axes = plt.subplots(1, 2, figsize=(14,5))

# Histogram
sns.histplot(df['number_diagnoses'], bins=15, kde=True, color="#A78BFA", ax=axes[0])
axes[0].set_title("Number of Diagnoses - Distribution")
axes[0].set_xlabel("number_diagnoses")
axes[0].set_ylabel("Count")

# Boxplot
sns.boxplot(y=df['number_diagnoses'], color="#9333EA", ax=axes[1])
axes[1].set_title("Number of Diagnoses - Boxplot")

plt.tight_layout()
plt.show()

# %%
categorical_features = [
    'max_glu_serum',
    'A1Cresult',
    'diag_1_group',
    'diag_2_group',
    'diag_3_group'
]

fig, axes = plt.subplots(3, 2, figsize=(16,14))
axes = axes.flatten()

for i, col in enumerate(categorical_features):
    ax = axes[i]
    sns.countplot(data=df, x=col, palette="Purples", ax=ax)
    ax.set_title(f"{col} Distribution")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")
    ax.tick_params(axis='x', rotation=45)

    # Add percentages on top of bars
    total = len(df)
    for p in ax.patches:
        height = p.get_height()
        pct = height / total * 100
        ax.text(
            p.get_x() + p.get_width() / 2.,  # X position: middle of bar
            height + 5,                      # Y position: a little above bar
            f'{pct:.1f}%',                   # Text
            ha="center", va="bottom", fontsize=10
        )

# Remove empty subplot if exists
fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2460640756.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette="Purples", ax=ax)
# /tmp/ipython-input-2460640756.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette="Purples", ax=ax)
# /tmp/ipython-input-2460640756.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette="Purples", ax=ax)
# /tmp/ipython-input-2460640756.py:14: FutureWarning:
#
# ...

# %% [markdown]
# put a comment here

# %% [markdown]
# ### Drugs

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

med_features = [
    'metformin', 'repaglinide', 'glimepiride', 'glipizide',
    'glyburide', 'pioglitazone', 'rosiglitazone',
    'insulin', 'diabetesMed', 'change'
]

fig, axes = plt.subplots(5, 2, figsize=(16,18))
axes = axes.flatten()

for i, col in enumerate(med_features):
    ax = axes[i]
    sns.countplot(data=df, x=col, ax=ax, palette="Purples")
    ax.set_title(f"{col} Distribution")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")
    ax.tick_params(axis='x', rotation=30)

    # Add percentages on top of bars
    total = len(df)
    for p in ax.patches:
        height = p.get_height()
        pct = height / total * 100
        ax.text(
            p.get_x() + p.get_width() / 2.,  # x-position: center of bar
            height + 5,                      # y-position: slightly above bar
            f'{pct:.1f}%',                   # text to display
            ha='center', va='bottom', fontsize=10
        )

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-176603722.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette="Purples")
# /tmp/ipython-input-176603722.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette="Purples")
# /tmp/ipython-input-176603722.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=ax, palette="Purples")
# /tmp/ipython-input-176603722.py:17: FutureWarning:
#
# ...

# %% [markdown]
# ### Target Variable

# %%
import matplotlib.pyplot as plt

# Count values
readmit_counts = df['readmitted'].value_counts()

# Define purplish color theme
colors = ["#C084FC", "#9333EA", "#6B21A8"]  # adjust depending on number of classes

plt.figure(figsize=(6,6))

plt.pie(
    readmit_counts,
    labels=readmit_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors[:len(readmit_counts)],
    textprops={'fontsize':12}
)

plt.title("Readmission Distribution", fontsize=14)
plt.show()

# %% [markdown]
# Now lets move on to **bivariate/multivariate analysis**

# %% [markdown]
# ## 5. Bivariate/multivariate analysis

# %% [markdown]
# ### Numerical vs Numerical

# %%
numerical_features = [
    'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications',
    'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses'
]
plt.figure(figsize=(10,8))
sns.heatmap(df[numerical_features].corr(), annot=True, cmap="Purples", fmt=".2f")
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Percentage table
ct = pd.crosstab(
    df['admission_type_id'],
    df['readmitted'],
    normalize='index'
) * 100

# Ensure consistent stacking order
ct = ct[[-1, 0, 1]]

# Purple shades
colors = ['#e9d5ff', '#a855f7', '#4c1d95']

# Plot
ax = ct.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6),
    color=colors
)

plt.title("Readmission Distribution by Admission Type")
plt.xlabel("Admission Type ID")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=0)

# Add percentage labels inside stacks
for i in range(len(ct)):
    cumulative = 0
    for col in ct.columns:
        value = ct.loc[ct.index[i], col]
        if value > 0:
            ax.text(
                i,
                cumulative + value / 2,
                f"{value:.1f}%",
                ha='center',
                va='center',
                fontsize=9,
                color='white' if value > 15 else 'black'
            )
        cumulative += value

plt.legend(title="Readmitted")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))

sns.regplot(
    data=df,
    x='number_emergency',
    y='number_inpatient',
    scatter_kws={'alpha':0.3},
    line_kws={'color':'purple'}
)

plt.title("Emergency Visits vs Inpatient Visits")
plt.show()

# %% [markdown]
# ### Numerical vs Categorical

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='admission_type_id', y='time_in_hospital', data=df, palette="Purples")
plt.title("Time in Hospital by Admission Type")
plt.show()
# Out:
# /tmp/ipython-input-3854923720.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='admission_type_id', y='time_in_hospital', data=df, palette="Purples")

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='change', y='time_in_hospital', data=df, palette="Purples")
plt.title("Time in Hospital by Change of medication")
plt.show()
# Out:
# /tmp/ipython-input-2576080269.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='change', y='time_in_hospital', data=df, palette="Purples")

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='age', y='time_in_hospital', data=df, palette="Purples")
plt.title("Time in Hospital by Age")
plt.show()
# Out:
# /tmp/ipython-input-103240958.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='age', y='time_in_hospital', data=df, palette="Purples")

# %% [markdown]
# ### Categorical vs Categorical

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Cross-tab: counts of readmitted per admission type
cross_tab = pd.crosstab(df['admission_type_id'], df['readmitted'])

# '<30': 1, '>30': 0, 'NO': -1

# Calculate percentages for each admission type
cross_tab_pct = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
cross_tab_pct.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6),
    color=["#C084FC", "#9333EA", "#6B21A8"]  # same purplish theme
)

plt.title("Readmission Proportion by Admission Type")
plt.ylabel("Percentage of Patients")
plt.xlabel("Admission Type ID")
plt.legend(title="Readmitted", bbox_to_anchor=(1.05, 1))
plt.xticks(rotation=0)

# Annotate percentages on bars
for idx, row in enumerate(cross_tab_pct.itertuples(index=False)):
    bottom = 0
    for i, pct in enumerate(row):
        if pct > 0:  # only annotate if value >0
            plt.text(
                idx, bottom + pct/2,
                f"{pct:.1f}%",
                ha='center', va='center', fontsize=10, color='white'
            )
            bottom += pct

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Cross-tab: counts of readmitted per admission type
cross_tab1 = pd.crosstab(df['medical_specialty_group_num'], df['readmitted'])

# 0 Male ,1 Female

# Calculate percentages for each admission type
cross_tab_pct = cross_tab1.div(cross_tab1.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
cross_tab_pct.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6),
    color=["#C084FC", "#9333EA", "#6B21A8"]  # same purplish theme
)

plt.title("Readmission Proportion by Medical Speciality")
plt.ylabel("Percentage of Patients")
plt.xlabel("Medical Speciality")
plt.legend(title="Readmitted", bbox_to_anchor=(1.05, 1))
plt.xticks(rotation=0)

# Annotate percentages on bars
for idx, row in enumerate(cross_tab_pct.itertuples(index=False)):
    bottom = 0
    for i, pct in enumerate(row):
        if pct > 0:  # only annotate if value >0
            plt.text(
                idx, bottom + pct/2,
                f"{pct:.1f}%",
                ha='center', va='center', fontsize=10, color='white'
            )
            bottom += pct

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Cross-tab: counts of readmitted per admission type
cross_tab1 = pd.crosstab(df['change'], df['readmitted'])

# 0 Male ,1 Female

# Calculate percentages for each admission type
cross_tab_pct = cross_tab1.div(cross_tab1.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
cross_tab_pct.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6),
    color=["#C084FC", "#9333EA", "#6B21A8"]  # same purplish theme
)

plt.title("Readmission Proportion by Change of medication")
plt.ylabel("Percentage of Patients")
plt.xlabel("Change of medication")
plt.legend(title="Readmitted", bbox_to_anchor=(1.05, 1))
plt.xticks(rotation=0)

# Annotate percentages on bars
for idx, row in enumerate(cross_tab_pct.itertuples(index=False)):
    bottom = 0
    for i, pct in enumerate(row):
        if pct > 0:  # only annotate if value >0
            plt.text(
                idx, bottom + pct/2,
                f"{pct:.1f}%",
                ha='center', va='center', fontsize=10, color='white'
            )
            bottom += pct

plt.tight_layout()
plt.show()

# %%
med_features = [
    'metformin', 'repaglinide', 'glimepiride', 'glipizide',
    'glyburide', 'pioglitazone', 'rosiglitazone',
    'insulin', 'diabetesMed', 'change','readmitted'
]

# Convert Yes/No to 1/0 for correlation
df_med_numeric = df[med_features].replace({'No':0, 'Yes':1, 'Steady':1, 'Up':1, 'Down':1})
plt.figure(figsize=(10,8))
sns.heatmap(df_med_numeric.corr(), annot=True, cmap="Purples", fmt=".2f")
plt.title("Correlation between Medications")
plt.show()

# %% [markdown]
# ### Analysis with Target Variables

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='race', hue='readmitted')
plt.title("Readmission by Race")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df, x='readmitted', y='time_in_hospital')
plt.title("Hospital Stay vs Readmission")
plt.show()

# %%
num_cols = [
    'time_in_hospital','num_lab_procedures','num_procedures',
    'num_medications','number_outpatient','number_emergency',
    'number_inpatient','number_diagnoses'
]


corr = df[num_cols + ['readmitted']].corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='Purples')
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(
    df[['number_inpatient','number_emergency',
        'num_medications','number_diagnoses',
        'readmitted']],
    hue='readmitted',
    diag_kind='kde'
)
plt.show()

# %%
insulin_readmit = (
    df.groupby(['insulin','readmitted'])
      .size()
      .reset_index(name='count')
)

# Calculate percentage within each insulin category
insulin_readmit['percentage'] = (
    insulin_readmit['count'] /
    insulin_readmit.groupby('insulin')['count'].transform('sum')
)

plt.figure(figsize=(6,4))
sns.barplot(data=insulin_readmit, x='insulin', y='percentage', hue='readmitted')
plt.title("Insulin vs Readmission Rate")
plt.show()

# %%
insulin_readmit = (
    df.groupby(['A1Cresult','readmitted'])
      .size()
      .reset_index(name='count')
)

# Calculate percentage within each insulin category
insulin_readmit['percentage'] = (
    insulin_readmit['count'] /
    insulin_readmit.groupby('A1Cresult')['count'].transform('sum')
)

plt.figure(figsize=(6,4))
sns.barplot(data=insulin_readmit, x='A1Cresult', y='percentage', hue='readmitted')
plt.title("A1Cresult vs Readmission Rate")
plt.show()

# %%
insulin_readmit = (
    df.groupby(['max_glu_serum','readmitted'])
      .size()
      .reset_index(name='count')
)

# Calculate percentage within each insulin category
insulin_readmit['percentage'] = (
    insulin_readmit['count'] /
    insulin_readmit.groupby('max_glu_serum')['count'].transform('sum')
)

plt.figure(figsize=(6,4))
sns.barplot(data=insulin_readmit, x='max_glu_serum', y='percentage', hue='readmitted')
plt.title("max_glu_serum vs Readmission Rate")
plt.show()

# %%
insulin_readmit = (
    df.groupby(['diabetesMed','readmitted'])
      .size()
      .reset_index(name='count')
)

# Calculate percentage within each insulin category
insulin_readmit['percentage'] = (
    insulin_readmit['count'] /
    insulin_readmit.groupby('diabetesMed')['count'].transform('sum')
)

plt.figure(figsize=(6,4))
sns.barplot(data=insulin_readmit, x='diabetesMed', y='percentage', hue='readmitted')
plt.title("diabetesMed vs Readmission Rate")
plt.show()

# %%
# Group by diag_1_group and readmitted, get counts
diag_readmit = df.groupby(['diag_1_group','readmitted']).size().reset_index(name='count')

# Compute percentage within each diag_1_group
diag_readmit['percentage'] = diag_readmit['count'] / diag_readmit.groupby('diag_1_group')['count'].transform('sum')

# Plot
plt.figure(figsize=(10,5))
sns.barplot(data=diag_readmit, x='diag_1_group', y='percentage', hue='readmitted')
plt.xticks(rotation=45)
plt.title("Primary Diagnosis vs Readmission Rate")
plt.show()
